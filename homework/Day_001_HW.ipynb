# %%
#HM1
import numpy as np
import matplotlib.pyplot as plt

# %%
# 與範例相同, 不另外解說
w = 3
b = 0.5
x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
# 與範例相同, 不另外解說
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
def mean_squared_error(y, yp):
    """
    計算 MSE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MSE
    """
    mse = MSE = (sum(y - yp)**2)/len(y)
    return mse

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
# Out:
# The Mean squared error is 1.117

# %% [markdown]
# 作業2
# Kaggle - Second Annual Data Science Bowl
# 在美國每天有1500人被診斷出心臟衰竭，而經由MRI影像得知的end-systolic 和 end-diastolic volumes，推算出EF數值是診斷病患心臟功能的黃金標準，但心臟科醫師斷一個影像需花費20分鐘的時間，利用資料科學的方式讓這個診斷流程夠有效率，可讓醫師畫更多時間在病患的照顧上。
# 此資料來源為 National Institutes of Health and Children's National Medical Center
# 此資料包含1000名自願者的MRI影像
# 解決辦法: 需先能自動畫出每個MRI影像中心室在收縮和舒張時的的範圍大小，再用已知的end-systolic 和 end-diastolic volumes，建立一套推算影像範圍小與實際心室體積的回歸公式。

# %%
作業3
想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：

1. 核心問題為何: 希望了解各地區在每天不同時間點的乘客需求數，再針對數量不同的時間點和地點調整派駐車輛，增加業績

2. 資料從何而來: 司機載客時回報的地點與時間，和車資

3. 蒐集而來的資料型態為何: 數值表格，結構性資料

4. 你要回答的問題，其如何評估:Root Mean Squared Logarithmic Error.
